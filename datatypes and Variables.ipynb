# %%
a=15

# %%
b=16
print(a,b)
# Out:
# 15 16

# %%
print("c")
# Out:
# c

# %%
a="waqas"
b="aziz"
print(a,b)
# Out:
# waqas aziz

# %%
print(a+b)
# Out:
# waqasaziz

# %%
print(a+ " " +b)
# Out:
# waqas aziz

# %%
print(ab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(ab)
#
# NameError: name 'ab' is not defined

# %%
ab="waqas aziz"?
# Out:
#   Cell In[9], line 1
#     ab="waqas aziz"?
#                    ^
# SyntaxError: invalid syntax

# %%
ab="waqas aziz"
print(ab)
# Out:
# waqas aziz

# %%
a=12
b=13
a,b=b,a
print("value of a after swapping is: ", a)
print("value of b after swapping is: ",b)
# Out:
# value of a after swapping is:  13
# value of b after swapping is:  12

# %%
a=12
A=13
print(a,A)
# Out:
# 12 13

# %%
std1,std2,std3,std4,std5=20,21,22,23,24
print(std1)
# Out:
# 20

# %%
print(std2)
# Out:
# 21

# %%
a=[12,13,14,15,15,17,18]
print(a)
# Out:
# [12, 13, 14, 15, 15, 17, 18]

# %%
a=b=c=1
print(a,b,c)
# Out:
# 1 1 1

# %%
a=1

# %%
b=1

# %%
print(a==b)
# Out:
# True

# %%
print(type(a==b))
# Out:
# <class 'bool'>

# %%
print(True)
# Out:
# True

# %%
true=12

# %%
a=12
b="12"
print(a==b)
# Out:
# False

# %%
a,b,c=12,13.0,"waqas"
print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# 12 <class 'int'>
# 13.0 <class 'float'>
# waqas <class 'str'>

# %%
#TypeCasting
a=12 #integer
b=float(a) #integer to float
c=str(a) #integer to string

# %%
print(a, type(a))
print(b,type(b))
print(c,type(c))
print(a,b,c)
# Out:
# 12 <class 'int'>
# 12.0 <class 'float'>
# 12 <class 'str'>
# 12 12.0 12
